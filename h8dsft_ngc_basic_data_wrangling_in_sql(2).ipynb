# %% [markdown]
# ID: civil-zodiac-412107

# %%
from google.colab import auth
from google.cloud import bigquery
import pandas as pd

# %%
auth.authenticate_user()
project_id = "civil-zodiac-412107"
client = bigquery.Client(project=project_id)

# %%
# put your query here
query = """
SELECT *
FROM `bigquery-public-data.austin_bikeshare.bikeshare_trips`
"""
# Set up the query
query_job = client.query(query).to_dataframe()
query_job
# Out:
#           trip_id       subscriber_type bike_id bike_type  \
# 0         4098776  24 Hour Walk Up Pass      24   classic
# 1         4083633  24 Hour Walk Up Pass       3   classic
# 2         4073980  24 Hour Walk Up Pass      24   classic
# 3         4072213              Local365      88   classic
# 4         3990481       Founding Member     555   classic
# ...           ...                   ...     ...       ...
# 2130004  32145088    Student Membership   21610  electric
# 2130005  32177210    Student Membership   19479  electric
# 2130006  32130552    Student Membership   21550  electric
# 2130007  32191359       Pay-as-you-ride   19196  electric
# 2130008  32201887    Student Membership   19479  electric
#
#                        start_time  start_station_id  \
# 0       2015-03-12 22:22:59+00:00              2546
# 1       2015-03-11 15:55:38+00:00              2712
# 2       2015-03-10 16:10:57+00:00              2545
# 3       2015-03-10 13:20:33+00:00              2823
# 4       2015-02-22 17:27:29+00:00              2546
# ...                           ...               ...
# 2130004 2023-12-11 20:18:20+00:00              7189
# 2130005 2023-12-16 13:20:51+00:00              7189
# 2130006 2023-12-09 21:13:06+00:00              7189
# 2130007 2023-12-19 11:55:04+00:00              7189
# 2130008 2023-12-21 20:36:42+00:00              7189
#
#                            start_station_name end_station_id  \
# 0                    ACC - West & 12th Street           2546
# 1                     Toomey Rd @ South Lamar           2712
# 2                     ACC - Rio Grande & 12th           2546
# 3        East 5th/Broadway @ Capital Metro HQ           2823
# 4                    ACC - West & 12th Street           2712
# ...                                       ...            ...
# 2130004                       28th/Rio Grande           7189
# 2130005                       28th/Rio Grande           7189
# 2130006                       28th/Rio Grande           7189
# 2130007                       28th/Rio Grande           7189
# 2130008                       28th/Rio Grande           7189
#
#                              end_station_name  duration_minutes
# 0                    ACC - West & 12th Street                46
# 1                     Toomey Rd @ South Lamar                92
# 2                    ACC - West & 12th Street                24
# 3        East 5th/Broadway @ Capital Metro HQ                 8
# 4                     Toomey Rd @ South Lamar                11
# ...                                       ...               ...
# 2130004                       28th/Rio Grande                50
# 2130005                       28th/Rio Grande                 2
# 2130006                       28th/Rio Grande                 3
# 2130007                       28th/Rio Grande               123
# 2130008                       28th/Rio Grande                 8
#
# [2130009 rows x 10 columns]

# %% [markdown]
# # Task 1

# %% [markdown]
# ## How many tables are in the austin_bikeshare dataset?

# %%
# put your query here
query = """
SELECT COUNT (*) AS table_count
FROM `bigquery-public-data.austin_bikeshare.INFORMATION_SCHEMA.TABLES`
"""
# Set up the query
query_job = client.query(query).to_dataframe()
query_job
# Out:
#    table_count
# 0            2

# %% [markdown]
# ## How many columns in the bikeshare_stations table have STRING data?

# %%
# put your query here
query = """
SELECT COUNT (*) AS jumlah_string
FROM `bigquery-public-data.austin_bikeshare.INFORMATION_SCHEMA.COLUMNS`
WHERE table_name = 'bikeshare_stations' AND data_type = 'STRING'
"""
# Set up the query
query_job = client.query(query).to_dataframe()
query_job
# Out:
#    jumlah_string
# 0              7

# %% [markdown]
# # Task 2

# %% [markdown]
# ## Retrieve all trips where the bike_id is not null and the duration is greater than 1000 minutes

# %%
# put your query here
query = """
SELECT * FROM `bigquery-public-data.austin_bikeshare.bikeshare_trips`
"""
# Set up the query
query_job = client.query(query).to_dataframe()
query_job
# Out:
#           trip_id       subscriber_type bike_id bike_type  \
# 0         4098766  24 Hour Walk Up Pass     306   classic
# 1         4073137              Local365     503   classic
# 2         3988277  24 Hour Walk Up Pass     464   classic
# 3         3988089  24 Hour Walk Up Pass     105   classic
# 4         3988064  24 Hour Walk Up Pass     100   classic
# ...           ...                   ...     ...       ...
# 2130004  32232084    Student Membership   21742  electric
# 2130005  32056332              Explorer   21790  electric
# 2130006  32131554    Student Membership   21659  electric
# 2130007  32142417    Student Membership   21742  electric
# 2130008  32069227    Student Membership   19675  electric
#
#                        start_time  start_station_id        start_station_name  \
# 0       2015-03-12 22:20:09+00:00              2546  ACC - West & 12th Street
# 1       2015-03-10 15:11:03+00:00              <NA>      Ready for deployment
# 2       2015-02-21 21:35:43+00:00              2546  ACC - West & 12th Street
# 3       2015-02-21 19:05:18+00:00              <NA>     MapJam at Pan Am Park
# 4       2015-02-21 18:59:26+00:00              <NA>     MapJam at Pan Am Park
# ...                           ...               ...                       ...
# 2130004 2023-12-31 07:06:40+00:00              7189           28th/Rio Grande
# 2130005 2023-12-01 22:25:58+00:00              7189           28th/Rio Grande
# 2130006 2023-12-10 02:21:43+00:00              7189           28th/Rio Grande
# 2130007 2023-12-11 15:23:34+00:00              7189           28th/Rio Grande
# 2130008 2023-12-03 15:49:21+00:00              7189           28th/Rio Grande
#
#         end_station_id                      end_station_name  duration_minutes
# 0                 2546              ACC - West & 12th Street                47
# 1                 2568               East 11th/Victory Grill                 8
# 2                 2546              ACC - West & 12th Street                42
# 3                 2823  East 5th/Broadway @ Capital Metro HQ                 8
# 4                 2568               East 11th/Victory Grill                20
# ...                ...                                   ...               ...
# 2130004           7189                       28th/Rio Grande                51
# 2130005           7189                       28th/Rio Grande                35
# 2130006           7189                       28th/Rio Grande                 3
# 2130007           7189                       28th/Rio Grande                26
# 2130008           7189                       28th/Rio Grande                 7
#
# [2130009 rows x 10 columns]

# %%
# put your query here
query = """
SELECT * FROM `bigquery-public-data.austin_bikeshare.bikeshare_trips`
WHERE bike_id IS NOT NULL AND duration_minutes > 1000
"""
# Set up the query
query_job = client.query(query).to_dataframe()
query_job
# Out:
#        trip_id                subscriber_type bike_id bike_type  \
# 0     10871188                        Walk Up     193   classic
# 1     10871199                        Walk Up     668   classic
# 2     11317281                        Walk Up     479   classic
# 3     21605993                       Local365    3212   classic
# 4     21532067  Single Trip (Pay-as-you-ride)     393   classic
# ...        ...                            ...     ...       ...
# 3631  27496076             Student Membership   18909  electric
# 3632  27866791             Student Membership   19085  electric
# 3633  29705983                        Local31   21789  electric
# 3634  29630616             Student Membership   19619  electric
# 3635  27357116             Student Membership   22196  electric
#
#                     start_time  start_station_id  \
# 0    2016-07-09 18:08:46+00:00              2562
# 1    2016-07-09 18:09:51+00:00              2562
# 2    2016-08-08 02:13:02+00:00              2561
# 3    2020-02-23 14:21:47+00:00              2540
# 4    2020-02-01 13:57:28+00:00              2822
# ...                        ...               ...
# 3631 2022-08-17 14:44:33+00:00              7188
# 3632 2022-09-17 12:56:13+00:00              7188
# 3633 2023-05-24 10:40:21+00:00              7189
# 3634 2023-05-15 13:11:21+00:00              7189
# 3635 2022-08-01 14:09:43+00:00              7189
#
#                                      start_station_name end_station_id  \
# 0                              San Jacinto & 8th Street           2562
# 1                              San Jacinto & 8th Street           2562
# 2     State Capitol Visitors Garage @ San Jacinto & ...           2561
# 3                                        17th/Guadalupe           2540
# 4                           East 6th/Robert T. Martinez           2544
# ...                                                 ...            ...
# 3631                                         22nd/Pearl           7189
# 3632                                         22nd/Pearl           7189
# 3633                                    28th/Rio Grande           7189
# 3634                                    28th/Rio Grande           7189
# 3635                                           28th/Rio           7189
#
#                                        end_station_name  duration_minutes
# 0                              San Jacinto & 8th Street              1087
# 1                              San Jacinto & 8th Street              1150
# 2     State Capitol Visitors Garage @ San Jacinto & ...              1311
# 3                                        17th/Guadalupe              1186
# 4                                   East 6th/Pedernales              1223
# ...                                                 ...               ...
# 3631                                           28th/Rio              1084
# 3632                                           28th/Rio              1198
# 3633                     23rd/San Jacinto @ DKR Stadium              1451
# 3634                                    28th/Rio Grande              1196
# 3635                                           28th/Rio              1138
#
# [3636 rows x 10 columns]

# %% [markdown]
# Filter trips where the trip_id is "Walk Up" and the end_station_name  is "Stolen".

# %%
# put your query here
query = """
SELECT *
FROM `bigquery-public-data.austin_bikeshare.bikeshare_trips`
WHERE subscriber_type = 'Walk Up' AND end_station_name = 'Stolen'
"""
# Set up the query
query_job = client.query(query).to_dataframe()
query_job.head()
# Out:
#     trip_id subscriber_type bike_id bike_type                start_time  \
# 0  13555129         Walk Up     578   classic 2017-01-27 01:35:26+00:00
# 1  13564817         Walk Up     393   classic 2017-01-28 04:57:28+00:00
# 2  11712091         Walk Up     327   classic 2016-09-02 06:37:15+00:00
# 3  11714202         Walk Up     122   classic 2016-09-02 09:00:56+00:00
# 4  13857913         Walk Up     135   classic 2017-02-26 14:32:45+00:00
#
#    start_station_id                                 start_station_name  \
# 0              2498            Convention Center / 4th St. @ MetroRail
# 1              2561  State Capitol Visitors Garage @ San Jacinto & ...
# 2              2565                               Trinity & 6th Street
# 3              2565                               Trinity & 6th Street
# 4              2566                      Pfluger Bridge @ W 2nd Street
#
#   end_station_id end_station_name  duration_minutes
# 0           None           Stolen              5189
# 1           None           Stolen              4833
# 2           None           Stolen              6118
# 3           None           Stolen              5974
# 4           None           Stolen              1404
